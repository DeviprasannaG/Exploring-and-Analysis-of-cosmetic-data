# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
df= pd.read_csv(r"C:\Users\gdevi\Desktop\final_dataset.csv", sep=",",encoding='latin-1')

# %%
df.price = pd.to_numeric(skincare.price, errors='coerce')

# %%
# Take the top 20 and least 20 brands based on the mean price
grouped_data = df.groupby('brand')['price'].agg(['mean', 'median', 'std'])
top = grouped_data.nlargest(40, 'mean')

# Plot the bar chart for the selected brands
top.plot(kind='bar', stacked=True, figsize=(18,6))
plt.title('Distribution of Price for Selected Brands')
plt.xlabel('Brand')
plt.ylabel('Price')
plt.show()

# Analyze the selected data
print(selected_brands)
# Out:
#                                                    mean    median  \
# brand
# La Prairie                                 87666.000000  87666.00
# Clive Christian                            77749.500000  77749.50
# LANEIGE                                    69000.000000  69000.00
# Skin+Illustrator                           21399.000000  21399.00
# Surratt                                    18289.790000  18289.79
# SPEEDLASH                                  17799.000000  17799.00
# MD                                         16343.000000  16343.00
# Giorgio Armani                             16199.000000  16199.00
# LashSense                                  15569.000000  15569.00
# Mojidecor                                  14005.000000  14005.00
# TOM FORD                                   14000.015152  12255.00
# BECCA                                      13699.000000  13699.00
# Susan+Posnick+Cosmetics                    13259.000000  13259.00
# BH Cosmetics                               12079.000000  12079.00
# Laura Mercier                              11425.666667  12699.00
# SISLEY                                     11399.000000  11399.00
# Mirenesse Cosmetics                        11199.000000  11199.00
# Mary Kay Cream Eye Color - Metallic Taupe  10999.000000  10999.00
# Make Up For Ever                           10770.600000   9899.00
# Tory Burch                                 10621.000000  10621.00
# Temptu                                     10499.000000  10499.00
# FantasyDay                                 10209.000000  10209.00
# Godefroy                                   10005.000000  10005.00
# Helena Rubinstein                           9999.000000   9999.00
# Viktor&Rolf                                 9967.400000  10457.60
# Tiffany & Co.                               9763.150000   9926.55
# Chloï¿½                                     9667.833333  10130.80
# Glitties Nail Art                           9599.000000   9599.00
# CHANEL                                      9535.328154   8171.00
# By Terry                                    9499.000000   9499.00
#
#                                                     std
# brand
# La Prairie                                          NaN
# Clive Christian                            23121.684638
# LANEIGE                                             NaN
# Skin+Illustrator                                    NaN
# Surratt                                     9900.612165
# SPEEDLASH                                           NaN
# MD                                                  NaN
# Giorgio Armani                              3295.117600
# LashSense                                           NaN
# Mojidecor                                           NaN
# TOM FORD                                    5106.928641
# BECCA                                               NaN
# Susan+Posnick+Cosmetics                             NaN
# BH Cosmetics                                        NaN
# Laura Mercier                               3000.022222
# SISLEY                                      1555.634919
# Mirenesse Cosmetics                                 NaN
# Mary Kay Cream Eye Color - Metallic Taupe           NaN
# Make Up For Ever                            2758.125142
# Tory Burch                                          NaN
# Temptu                                      6929.646456
# FantasyDay                                          NaN
# Godefroy                                            NaN
# Helena Rubinstein                                   NaN
# Viktor&Rolf                                 5244.202445
# Tiffany & Co.                               1724.431354
# Chloï¿½                                     3142.070544
# Glitties Nail Art                                   NaN
# CHANEL                                      5606.581528
# By Terry                                            NaN

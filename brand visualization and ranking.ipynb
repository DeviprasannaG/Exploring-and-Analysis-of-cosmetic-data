# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
cosmetic_df= pd.read_csv(r"C:\Users\gdevi\Desktop\final_dataset.csv",sep=",",encoding='latin-1')
cosmetic_df
# Out:
#                                             product_name   website country  \
# 0      Carlton London Incense Eau da parfum, Premium ...  Flipkart   India
# 1      CHARLENE SPRAY MIST PERFUME 30 - INTIMATE (PAC...  Flipkart   India
# 2      CHARLENE SPRAY MIST PERFUME 30 - INTIMATE (PAC...  Flipkart   India
# 3      DENVER Black Code Perfume - 60 | Eau de Parfum...  Flipkart   India
# 4      Denver Hamilton Perfume - 100 | Long Lasting P...  Flipkart   India
# ...                                                  ...       ...     ...
# 12610  Bright Future - Smoothing & Brightening Concea...   Sephora   India
# 12611  Bright Future - Smoothing & Brightening Concea...   Sephora   India
# 12612                     Starlaa Rosy Bronze Blush Mini   Sephora   India
# 12613      Terra Golden Brick Red Blush Travel Size Mini   Sephora   India
# 12614       Peachin' Golden Peach Blush Travel Size Mini   Sephora   India
#
# ...

# %%
cosmetic_df.noofratings= pd.to_numeric(cosmetic_df.noofratings, errors='coerce')
cosmetic_df.rating= pd.to_numeric(cosmetic_df.rating, errors='coerce')

# %%
# Sort the brands based on rating and number of ratings
brand_data = cosmetic_df.groupby('brand').agg({'rating': 'mean', 'noofratings': 'sum'})
sorted_brands = brand_data.sort_values(['rating', 'noofratings'], ascending=False)
sorted_brands['CompositeRanking'] = (0.7 * sorted_brands['rating']) + (0.3 * sorted_brands['noofratings'])

# Rank the brands based on their position in the sorted list
ranked_brands = sorted_brands.sort_values(by='CompositeRanking')
ranked_brands['Rank'] = ranked_brands['CompositeRanking'].rank(method='dense', ascending=False)

# Select only the Brand and Rank columns and print the resulting DataFrame
print(ranked_brands.sort_values('Rank'))
# Out:
#                            rating  noofratings  CompositeRanking  Rank
# brand
# Maybelline               4.155128     745281.0     223587.208590   1.0
# Nyx Professional Makeup  4.081818     226099.0      67832.557273   2.0
# LAKMï¿½                  4.041111     205889.0      61769.528778   3.0
# L'Orï¿½ï¿½ï¿½ï           4.281818     154721.0      46419.297273   4.0
# SWISS BEAUTY             3.906569     151529.0      45461.434599   5.0
# ...                           ...          ...               ...   ...
# ZYZHT                         NaN          0.0               NaN   NaN
# Zodak                         NaN          0.0               NaN   NaN
# Zuii Organic                  NaN          0.0               NaN   NaN
# ecovani                       NaN          0.0               NaN   NaN
# panchvati                     NaN          0.0               NaN   NaN
#
# [1753 rows x 4 columns]
